# %%
from exclude_comment4 import exclude_comment

# %%
with open('test.py', 'r', encoding='utf-8') as f:
    text = f.read()
print(text)
# Out:
# import pandas
# """
# test
# \\"""
# '''
# test'''
# #コメント
# a = 1
# """
# test\\"""
# print(a)
# a = "1"
# a = '1'
# a = """\\1"""
# a = '''1'''
# print("""1""")
# print('''1''')
# print("2")
# print('1')
# #$pppp
# def test():
#     '''
#     test
#     '''
#     print('ok')
#
# a = "\'\""
# if a == "\\'\\\"":
#     print('ok')
#     """test
#     """
# #plk
#
# if a == '\\\'\""':
#     print('ok'+
#           'ok')
#     print('ok'+
#           '')
#     print('ok'+
#           '''test'''
#     )
#     print('ok'+
#     '''test'''
#     )
#     """test
#     """
#     '''test'''
# #plk

# %%
print(exclude_comment(text, 'py'))
# Out:
# import pandas
#
#
#
# a = 1
#
# print(a)
# a = "1"
# a = '1'
# a = """\\1"""
# a = '''1'''
# print("""1""")
# print('''1''')
# print("2")
# print('1')
#
# def test():
#
#     print('ok')
#
# a = "\'\""
# if a == "\\'\\\"":
#     print('ok')
#
#
#
# if a == '\\\'\""':
#     print('ok'+
#           'ok')
#     print('ok'+
#           '')
#     print('ok'+
#           '''test'''
#     )
#     print('ok'+
#     '''test'''
#     )

# %%
from io import StringIO
import tokenize
def remove_comments_and_docstrings(source):
    """
    Returns 'source' minus comments and docstrings.
    """
    io_obj = StringIO(source)
    out = ""
    prev_toktype = tokenize.INDENT
    last_lineno = -1
    last_col = 0
    for tok in tokenize.generate_tokens(io_obj.readline):
        print(tok)
        token_type = tok[0]
        token_string = tok[1]
        #start_line:トークンのある行
        start_line, start_col = tok[2]
        end_line, end_col = tok[3]
        ltext = tok[4]
        # The following two conditionals preserve indentation.
        # This is necessary because we're not using tokenize.untokenize()
        # (because it spits out code with copious amounts of oddly-placed
        # whitespace).
        if start_line > last_lineno:
            last_col = 0
        if start_col > last_col:
            out += (" " * (start_col - last_col))
        # Remove comments:
        if token_type == tokenize.COMMENT:
            pass
        # This series of conditionals removes docstrings:
        elif token_type == tokenize.STRING:
            #トークンタイプがSTRINGの前にトークンタイプがINDENTだとドックストリング
            if prev_toktype != tokenize.INDENT:
                
        # This is likely a docstring; double-check we're not inside an operator:
                if prev_toktype != tokenize.NEWLINE:
                    #NEWLINEとは
                    # Note regarding NEWLINE vs NL: The tokenize module
                    # differentiates between newlines that start a new statement
                    # and newlines inside of operators such as parens（）〇括弧, brackes[]各括弧,
                    # and curly braces｛｝波括弧.  Newlines inside of operators are
                    # NEWLINE and newlines that start new code are NL.
                    # Catch whole-module docstrings:
                    # if start_col > 0:
                        # Unlabelled indentation means we're inside an operator
                    out += token_string
                    # Note regarding the INDENT token: The tokenize module does
                    # not label indentation inside of an operator (parens,
                    # brackets, and curly braces) as actual indentation.
                    # For example:
                    # def foo():
                    #     "The spaces before this docstring are tokenize.INDENT"
                    #     test = [
                    #         "The spaces before this string do not get a token"
                    #     ]
        else:
            out += token_string
        prev_toktype = token_type
        last_col = end_col
        last_lineno = end_line
    return out

# %%
print(remove_comments_and_docstrings(text))
# Out:
# TokenInfo(type=1 (NAME), string='import', start=(1, 0), end=(1, 6), line='import pandas\n')
# TokenInfo(type=1 (NAME), string='pandas', start=(1, 7), end=(1, 13), line='import pandas\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(1, 13), end=(1, 14), line='import pandas\n')
# TokenInfo(type=3 (STRING), string='"""\ntest\n\\\\"""', start=(2, 0), end=(4, 5), line='"""\ntest\n\\\\"""\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(4, 5), end=(4, 6), line='\\\\"""\n')
# TokenInfo(type=3 (STRING), string="'''\ntest'''", start=(5, 0), end=(6, 7), line="'''\ntest'''\n")
# TokenInfo(type=4 (NEWLINE), string='\n', start=(6, 7), end=(6, 8), line="test'''\n")
# TokenInfo(type=60 (COMMENT), string='#コメント', start=(7, 0), end=(7, 5), line='#コメント\n')
# TokenInfo(type=61 (NL), string='\n', start=(7, 5), end=(7, 6), line='#コメント\n')
# TokenInfo(type=1 (NAME), string='a', start=(8, 0), end=(8, 1), line='a = 1\n')
# TokenInfo(type=54 (OP), string='=', start=(8, 2), end=(8, 3), line='a = 1\n')
# TokenInfo(type=2 (NUMBER), string='1', start=(8, 4), end=(8, 5), line='a = 1\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(8, 5), end=(8, 6), line='a = 1\n')
# TokenInfo(type=3 (STRING), string='""" \ntest\\\\"""', start=(9, 0), end=(10, 9), line='""" \ntest\\\\"""\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(10, 9), end=(10, 10), line='test\\\\"""\n')
# TokenInfo(type=1 (NAME), string='print', start=(11, 0), end=(11, 5), line='print(a)\n')
# TokenInfo(type=54 (OP), string='(', start=(11, 5), end=(11, 6), line='print(a)\n')
# TokenInfo(type=1 (NAME), string='a', start=(11, 6), end=(11, 7), line='print(a)\n')
# TokenInfo(type=54 (OP), string=')', start=(11, 7), end=(11, 8), line='print(a)\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(11, 8), end=(11, 9), line='print(a)\n')
# TokenInfo(type=1 (NAME), string='a', start=(12, 0), end=(12, 1), line='a = "1"\n')
# TokenInfo(type=54 (OP), string='=', start=(12, 2), end=(12, 3), line='a = "1"\n')
# TokenInfo(type=3 (STRING), string='"1"', start=(12, 4), end=(12, 7), line='a = "1"\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(12, 7), end=(12, 8), line='a = "1"\n')
# TokenInfo(type=1 (NAME), string='a', start=(13, 0), end=(13, 1), line="a = '1'\n")
# TokenInfo(type=54 (OP), string='=', start=(13, 2), end=(13, 3), line="a = '1'\n")
# TokenInfo(type=3 (STRING), string="'1'", start=(13, 4), end=(13, 7), line="a = '1'\n")
# TokenInfo(type=4 (NEWLINE), string='\n', start=(13, 7), end=(13, 8), line="a = '1'\n")
# TokenInfo(type=1 (NAME), string='a', start=(14, 0), end=(14, 1), line='a = """\\\\1"""\n')
# TokenInfo(type=54 (OP), string='=', start=(14, 2), end=(14, 3), line='a = """\\\\1"""\n')
# TokenInfo(type=3 (STRING), string='"""\\\\1"""', start=(14, 4), end=(14, 13), line='a = """\\\\1"""\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(14, 13), end=(14, 14), line='a = """\\\\1"""\n')
# TokenInfo(type=1 (NAME), string='a', start=(15, 0), end=(15, 1), line="a = '''1'''\n")
# TokenInfo(type=54 (OP), string='=', start=(15, 2), end=(15, 3), line="a = '''1'''\n")
# TokenInfo(type=3 (STRING), string="'''1'''", start=(15, 4), end=(15, 11), line="a = '''1'''\n")
# TokenInfo(type=4 (NEWLINE), string='\n', start=(15, 11), end=(15, 12), line="a = '''1'''\n")
# TokenInfo(type=1 (NAME), string='print', start=(16, 0), end=(16, 5), line='print("""1""")\n')
# TokenInfo(type=54 (OP), string='(', start=(16, 5), end=(16, 6), line='print("""1""")\n')
# TokenInfo(type=3 (STRING), string='"""1"""', start=(16, 6), end=(16, 13), line='print("""1""")\n')
# TokenInfo(type=54 (OP), string=')', start=(16, 13), end=(16, 14), line='print("""1""")\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(16, 14), end=(16, 15), line='print("""1""")\n')
# TokenInfo(type=1 (NAME), string='print', start=(17, 0), end=(17, 5), line="print('''1''')\n")
# TokenInfo(type=54 (OP), string='(', start=(17, 5), end=(17, 6), line="print('''1''')\n")
# TokenInfo(type=3 (STRING), string="'''1'''", start=(17, 6), end=(17, 13), line="print('''1''')\n")
# TokenInfo(type=54 (OP), string=')', start=(17, 13), end=(17, 14), line="print('''1''')\n")
# TokenInfo(type=4 (NEWLINE), string='\n', start=(17, 14), end=(17, 15), line="print('''1''')\n")
# TokenInfo(type=1 (NAME), string='print', start=(18, 0), end=(18, 5), line='print("2")\n')
# TokenInfo(type=54 (OP), string='(', start=(18, 5), end=(18, 6), line='print("2")\n')
# TokenInfo(type=3 (STRING), string='"2"', start=(18, 6), end=(18, 9), line='print("2")\n')
# TokenInfo(type=54 (OP), string=')', start=(18, 9), end=(18, 10), line='print("2")\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(18, 10), end=(18, 11), line='print("2")\n')
# TokenInfo(type=1 (NAME), string='print', start=(19, 0), end=(19, 5), line="print('1')\n")
# TokenInfo(type=54 (OP), string='(', start=(19, 5), end=(19, 6), line="print('1')\n")
# TokenInfo(type=3 (STRING), string="'1'", start=(19, 6), end=(19, 9), line="print('1')\n")
# TokenInfo(type=54 (OP), string=')', start=(19, 9), end=(19, 10), line="print('1')\n")
# TokenInfo(type=4 (NEWLINE), string='\n', start=(19, 10), end=(19, 11), line="print('1')\n")
# TokenInfo(type=60 (COMMENT), string='#$pppp', start=(20, 0), end=(20, 6), line='#$pppp\n')
# TokenInfo(type=61 (NL), string='\n', start=(20, 6), end=(20, 7), line='#$pppp\n')
# TokenInfo(type=1 (NAME), string='def', start=(21, 0), end=(21, 3), line='def test():\n')
# TokenInfo(type=1 (NAME), string='test', start=(21, 4), end=(21, 8), line='def test():\n')
# TokenInfo(type=54 (OP), string='(', start=(21, 8), end=(21, 9), line='def test():\n')
# TokenInfo(type=54 (OP), string=')', start=(21, 9), end=(21, 10), line='def test():\n')
# TokenInfo(type=54 (OP), string=':', start=(21, 10), end=(21, 11), line='def test():\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(21, 11), end=(21, 12), line='def test():\n')
# TokenInfo(type=5 (INDENT), string='    ', start=(22, 0), end=(22, 4), line="    '''\n")
# TokenInfo(type=3 (STRING), string="'''\n    test\n    '''", start=(22, 4), end=(24, 7), line="    '''\n    test\n    '''\n")
# TokenInfo(type=4 (NEWLINE), string='\n', start=(24, 7), end=(24, 8), line="    '''\n")
# TokenInfo(type=1 (NAME), string='print', start=(25, 4), end=(25, 9), line="    print('ok')\n")
# TokenInfo(type=54 (OP), string='(', start=(25, 9), end=(25, 10), line="    print('ok')\n")
# TokenInfo(type=3 (STRING), string="'ok'", start=(25, 10), end=(25, 14), line="    print('ok')\n")
# TokenInfo(type=54 (OP), string=')', start=(25, 14), end=(25, 15), line="    print('ok')\n")
# TokenInfo(type=4 (NEWLINE), string='\n', start=(25, 15), end=(25, 16), line="    print('ok')\n")
# TokenInfo(type=61 (NL), string='\n', start=(26, 1), end=(26, 2), line=' \n')
# TokenInfo(type=6 (DEDENT), string='', start=(27, 0), end=(27, 0), line='a = "\\\'\\""  \n')
# TokenInfo(type=1 (NAME), string='a', start=(27, 0), end=(27, 1), line='a = "\\\'\\""  \n')
# TokenInfo(type=54 (OP), string='=', start=(27, 2), end=(27, 3), line='a = "\\\'\\""  \n')
# TokenInfo(type=3 (STRING), string='"\\\'\\""', start=(27, 4), end=(27, 10), line='a = "\\\'\\""  \n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(27, 12), end=(27, 13), line='a = "\\\'\\""  \n')
# TokenInfo(type=1 (NAME), string='if', start=(28, 0), end=(28, 2), line='if a == "\\\\\'\\\\\\"":\n')
# TokenInfo(type=1 (NAME), string='a', start=(28, 3), end=(28, 4), line='if a == "\\\\\'\\\\\\"":\n')
# TokenInfo(type=54 (OP), string='==', start=(28, 5), end=(28, 7), line='if a == "\\\\\'\\\\\\"":\n')
# TokenInfo(type=3 (STRING), string='"\\\\\'\\\\\\""', start=(28, 8), end=(28, 17), line='if a == "\\\\\'\\\\\\"":\n')
# TokenInfo(type=54 (OP), string=':', start=(28, 17), end=(28, 18), line='if a == "\\\\\'\\\\\\"":\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(28, 18), end=(28, 19), line='if a == "\\\\\'\\\\\\"":\n')
# TokenInfo(type=5 (INDENT), string='    ', start=(29, 0), end=(29, 4), line="    print('ok')\n")
# TokenInfo(type=1 (NAME), string='print', start=(29, 4), end=(29, 9), line="    print('ok')\n")
# TokenInfo(type=54 (OP), string='(', start=(29, 9), end=(29, 10), line="    print('ok')\n")
# TokenInfo(type=3 (STRING), string="'ok'", start=(29, 10), end=(29, 14), line="    print('ok')\n")
# TokenInfo(type=54 (OP), string=')', start=(29, 14), end=(29, 15), line="    print('ok')\n")
# TokenInfo(type=4 (NEWLINE), string='\n', start=(29, 15), end=(29, 16), line="    print('ok')\n")
# TokenInfo(type=3 (STRING), string='"""test\n    """', start=(30, 4), end=(31, 7), line='    """test\n    """\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(31, 7), end=(31, 8), line='    """\n')
# TokenInfo(type=60 (COMMENT), string='#plk', start=(32, 0), end=(32, 4), line='#plk\n')
# TokenInfo(type=61 (NL), string='\n', start=(32, 4), end=(32, 5), line='#plk\n')
# TokenInfo(type=61 (NL), string='\n', start=(33, 0), end=(33, 1), line='\n')
# TokenInfo(type=6 (DEDENT), string='', start=(34, 0), end=(34, 0), line='if a == \'\\\\\\\'\\""\':\n')
# TokenInfo(type=1 (NAME), string='if', start=(34, 0), end=(34, 2), line='if a == \'\\\\\\\'\\""\':\n')
# TokenInfo(type=1 (NAME), string='a', start=(34, 3), end=(34, 4), line='if a == \'\\\\\\\'\\""\':\n')
# TokenInfo(type=54 (OP), string='==', start=(34, 5), end=(34, 7), line='if a == \'\\\\\\\'\\""\':\n')
# TokenInfo(type=3 (STRING), string='\'\\\\\\\'\\""\'', start=(34, 8), end=(34, 17), line='if a == \'\\\\\\\'\\""\':\n')
# TokenInfo(type=54 (OP), string=':', start=(34, 17), end=(34, 18), line='if a == \'\\\\\\\'\\""\':\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(34, 18), end=(34, 19), line='if a == \'\\\\\\\'\\""\':\n')
# TokenInfo(type=5 (INDENT), string='    ', start=(35, 0), end=(35, 4), line="    print('ok'+\n")
# TokenInfo(type=1 (NAME), string='print', start=(35, 4), end=(35, 9), line="    print('ok'+\n")
# TokenInfo(type=54 (OP), string='(', start=(35, 9), end=(35, 10), line="    print('ok'+\n")
# TokenInfo(type=3 (STRING), string="'ok'", start=(35, 10), end=(35, 14), line="    print('ok'+\n")
# TokenInfo(type=54 (OP), string='+', start=(35, 14), end=(35, 15), line="    print('ok'+\n")
# TokenInfo(type=61 (NL), string='\n', start=(35, 15), end=(35, 16), line="    print('ok'+\n")
# TokenInfo(type=3 (STRING), string="'ok'", start=(36, 10), end=(36, 14), line="          'ok')\n")
# TokenInfo(type=54 (OP), string=')', start=(36, 14), end=(36, 15), line="          'ok')\n")
# TokenInfo(type=4 (NEWLINE), string='\n', start=(36, 15), end=(36, 16), line="          'ok')\n")
# TokenInfo(type=1 (NAME), string='print', start=(37, 4), end=(37, 9), line="    print('ok'+\n")
# TokenInfo(type=54 (OP), string='(', start=(37, 9), end=(37, 10), line="    print('ok'+\n")
# TokenInfo(type=3 (STRING), string="'ok'", start=(37, 10), end=(37, 14), line="    print('ok'+\n")
# TokenInfo(type=54 (OP), string='+', start=(37, 14), end=(37, 15), line="    print('ok'+\n")
# TokenInfo(type=61 (NL), string='\n', start=(37, 15), end=(37, 16), line="    print('ok'+\n")
# TokenInfo(type=3 (STRING), string="''", start=(38, 10), end=(38, 12), line="          '')\n")
# TokenInfo(type=54 (OP), string=')', start=(38, 12), end=(38, 13), line="          '')\n")
# TokenInfo(type=4 (NEWLINE), string='\n', start=(38, 13), end=(38, 14), line="          '')\n")
# TokenInfo(type=1 (NAME), string='print', start=(39, 4), end=(39, 9), line="    print('ok'+\n")
# TokenInfo(type=54 (OP), string='(', start=(39, 9), end=(39, 10), line="    print('ok'+\n")
# TokenInfo(type=3 (STRING), string="'ok'", start=(39, 10), end=(39, 14), line="    print('ok'+\n")
# TokenInfo(type=54 (OP), string='+', start=(39, 14), end=(39, 15), line="    print('ok'+\n")
# TokenInfo(type=61 (NL), string='\n', start=(39, 15), end=(39, 16), line="    print('ok'+\n")
# TokenInfo(type=3 (STRING), string="'''test'''", start=(40, 10), end=(40, 20), line="          '''test'''\n")
# TokenInfo(type=61 (NL), string='\n', start=(40, 20), end=(40, 21), line="          '''test'''\n")
# TokenInfo(type=54 (OP), string=')', start=(41, 4), end=(41, 5), line='    )\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(41, 5), end=(41, 6), line='    )\n')
# TokenInfo(type=1 (NAME), string='print', start=(42, 4), end=(42, 9), line="    print('ok'+\n")
# TokenInfo(type=54 (OP), string='(', start=(42, 9), end=(42, 10), line="    print('ok'+\n")
# TokenInfo(type=3 (STRING), string="'ok'", start=(42, 10), end=(42, 14), line="    print('ok'+\n")
# TokenInfo(type=54 (OP), string='+', start=(42, 14), end=(42, 15), line="    print('ok'+\n")
# TokenInfo(type=61 (NL), string='\n', start=(42, 15), end=(42, 16), line="    print('ok'+\n")
# TokenInfo(type=3 (STRING), string="'''test'''", start=(43, 4), end=(43, 14), line="    '''test'''\n")
# TokenInfo(type=61 (NL), string='\n', start=(43, 14), end=(43, 15), line="    '''test'''\n")
# TokenInfo(type=54 (OP), string=')', start=(44, 4), end=(44, 5), line='    )\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(44, 5), end=(44, 6), line='    )\n')
# TokenInfo(type=3 (STRING), string='"""test\n    """', start=(45, 4), end=(46, 7), line='    """test\n    """\n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(46, 7), end=(46, 8), line='    """\n')
# TokenInfo(type=3 (STRING), string="'''test'''", start=(47, 4), end=(47, 14), line="    '''test'''\n")
# TokenInfo(type=4 (NEWLINE), string='\n', start=(47, 14), end=(47, 15), line="    '''test'''\n")
# TokenInfo(type=60 (COMMENT), string='#plk', start=(48, 0), end=(48, 4), line='#plk\n')
# TokenInfo(type=61 (NL), string='\n', start=(48, 4), end=(48, 5), line='#plk\n')
# TokenInfo(type=6 (DEDENT), string='', start=(49, 0), end=(49, 0), line='')
# TokenInfo(type=0 (ENDMARKER), string='', start=(49, 0), end=(49, 0), line='')
# import pandas
#
#
#
# a = 1
#
# print(a)
# a = "1"
# a = '1'
# a = """\\1"""
# a = '''1'''
# print("""1""")
# print('''1''')
# print("2")
# print('1')
#
# def test():
#
#     print('ok')
#
# a = "\'\""
# if a == "\\'\\\"":
#     print('ok')
#
#
#
# if a == '\\\'\""':
#     print('ok'+
#           'ok')
#     print('ok'+
#           '')
#     print('ok'+
#           '''test'''
#     )
#     print('ok'+
#     '''test'''
#     )
