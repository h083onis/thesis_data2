# %%
import numpy as np
import pickle

# %%
# data = pickle.load(open('../resource/cc2vec_data/data/jit/qt_train.pkl', 'rb'))
data = pickle.load(open('../resource/deepjit_data/openstack_test.pkl', 'rb'))

# %%
len(data)
# Out:
# 4

# %%
id, labels, msgs, codes = data

# %%
id
# Out:
# ['844a228c3c42dac802a82510eb17fcfaccb0e1f8',
#  '37627645e47d35643454a84ae4a8c682ee0b18eb',
#  'e1165ce1180bba1a11098cfacfe3c722a084dbcf',
#  '1b9961c4b6785d85e98223f576bd839c0212b3a7',
#  'f184a386271b8305023c90186244a370727b2535',
#  '010e9dbd124060a6f75722aa146fde0f3ff69ab7',
#  '233b8ff70541cdcd059c8ef0e4d9dac7952adfb2',
#  'c9f15e3a51658c6b406521d87a95e94f25edf977',
#  'e1df9606c1cb54db6f9e91fb59f0f6c7636b334c',
#  'ff6a3dc031d782d01607e28c8bd3fb5aa396bb16',
#  '07d1e0468a5146cb69ab9906af4c854e871f6b8e',
#  'e982536084681328e912db7cd5d8a6b3e0b03b21',
#  'eb1e9ae114eccae373157c5391d06c97eec1e0a2',
#  '74a8601916ca1cfd1e6c1778c607614f916b728d',
#  'e7f3a9865e4c9e8891147421f0da7e04d69896f0',
#  'abb752763345053b018a25eca932bd4193df72c1',
#  '83cc9b40c54ed36b49af902aa8e9f659836c22b1',
#  '152e460a004e55dd02e6e8363401302da3bd43b4',
#  'f5fa0224686c259188e6b85115fa16939c20cb29',
#  '0493c803ae9612f87ed028e1a39e880aead5bdcb',
#  '6e30bbc126a1ad4eb87e735c812832f4fcc0054e',
# ...

# %%
if '001d36c97eac77410f7dd32290d2142abfb19fa0' in id:
    print('Ok')

# %%
msgs[0]
# Out:
# "import the linux header linux/perf_event.h imported from linux 's own git , at v3.7 : include/uapi/linux/perf_event.h ( blob sha-1 is 4f63c05d27c91d04569971ea4a2c4849203c36a9 ) . we can not rely on the file being shipped by distributions . older versions did not have all fields in the perf_event_attr structure . if those bits are enabled at runtime , the kernel will simply reject the perf_open call ( -einval ) . currently , this can only happen with the non-default options exclude_guest and exclude_host . change-id : ib329e52c21d6969406da0cf33de823d721d94206 reviewed-by : lars knoll < lars.knoll @ digia.com >"

# %%
len(id)
# Out:
# 23133

# %%
for i in range(len(id)):
    if 'ff3e2fbe2134fe0ae8c5427b91424c6a585c2dae' == id[i]:
        print(codes[i])

# %%
data = pickle.load(open('../resource/cc2vec_data/data/jit/qt_test.pkl', 'rb'))

# %%
id,labels,msgs,codes = data

# %%
if 'd2af738f023c25a6a2f82081e3f71037ab67e046' in msgs:
    print('ok')

# %%
import pickle
data = pickle.load(open('../resource/deepjit_data/qt_train.pkl', 'rb'))
data2 = pickle.load(open('../resource/deepjit_data/qt_test.pkl', 'rb'))

# %%
ids, labels, msgs, codes = data
ids2, labels2, msgs2, codes2 = data2
id_list = ids + ids2

# %%
import pandas as pd
df = pd.read_csv('../resource/pre_process_data/qt_reponame.csv', index_col=0, header=0)
commit_list = list(df['commit_id'])

# %%
tmp_list = []
print(len(id_list))
print(len(commit_list))
for id in id_list:
    if id not in commit_list:
        tmp_list.append(id)
len(tmp_list)
# Out:
# 25704
# 25150
# 4920

# %%
tmp_list[0]
# Out:
# 'be4db73231611d27522aab41840de9daafae9079'

# %%
if 'ffeadf7a7c09971fab09ed08b1f3f503c6facb7e' in tmp_list:
    print('ok')
